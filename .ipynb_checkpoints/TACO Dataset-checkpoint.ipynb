# %% [markdown]
# ## Machine Learning Waste Detection: TACO Dataset Processing

# %% [markdown]
# In this notebook, we process the TACO (Trash Annotations in Context) Dataset and get it ready for data augmentation and training.

# %% [markdown]
# #### Import relevant libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
from io import BytesIO
from matplotlib import image
from PIL import Image
import urllib.request
import cv2
import json

# %% [markdown]
# Some useful code for reading images later:

# %% [markdown]
# #### Read annotations from json file

# %% [markdown]
# First get all of the annotations into a dataframe:

# %%
with open('/Users/gautamchauhan/Desktop/MAPS Summer Internship/TACO/annotations.json') as json_data:
    data = json.load(json_data)
    df = pd.json_normalize(data)

# %%
df
# Out:
#                                               images  \
# 0  [{'id': 0, 'width': 1537, 'height': 2049, 'fil...
#
#                                          annotations  \
# 0  [{'id': 1, 'image_id': 0, 'category_id': 6, 's...
#
#                                    scene_annotations licenses  \
# 0  [{'image_id': 0, 'background_ids': [1]}, {'ima...       []
#
#                                           categories  \
# 0  [{'supercategory': 'Aluminium foil', 'id': 0, ...
#
#                                     scene_categories  info.year info.version  \
# 0  [{'id': 0, 'name': 'Clean'}, {'id': 1, 'name':...       2019         None
#
#   info.description info.contributor info.url                 info.date_created
# 0             TACO             None     None  2019-12-19T16:11:15.258399+00:00

# %%
scene_categories = df["scene_categories"][0]
scene_categories
# Out:
# [{'id': 0, 'name': 'Clean'},
#  {'id': 1, 'name': 'Indoor, Man-made'},
#  {'id': 2, 'name': 'Pavement'},
#  {'id': 3, 'name': 'Sand, Dirt, Pebbles'},
#  {'id': 4, 'name': 'Trash'},
#  {'id': 5, 'name': 'Vegetation'},
#  {'id': 6, 'name': 'Water'}]

# %% [markdown]
# Filter the dataset according to the background scene. Specifically, we will filter out the "Indoor, Man-made" category and the "Pavement" category, because images in these categories often contain environments unrealistic to our dataset.
#
# We will also filter category "7" out because this does not appear in the list of scene categories and I'm not sure what kind of background it refers to.

# %%
scene_annotations = df["scene_annotations"][0]
scene_annotations[0:10]
# Out:
# [{'image_id': 0, 'background_ids': [1]},
#  {'image_id': 1, 'background_ids': [1]},
#  {'image_id': 2, 'background_ids': [2]},
#  {'image_id': 3, 'background_ids': [5]},
#  {'image_id': 4, 'background_ids': [5]},
#  {'image_id': 5, 'background_ids': [1]},
#  {'image_id': 6, 'background_ids': [1, 7]},
#  {'image_id': 7, 'background_ids': [2]},
#  {'image_id': 8, 'background_ids': [2, 5]},
#  {'image_id': 9, 'background_ids': [1]}]

# %%
# Find all the image ids we want to remove
unsuitable_ids = []
for image_dict in scene_annotations:
    background_ids = image_dict["background_ids"]
    if 1 in background_ids or 2 in background_ids or 7 in background_ids:
        unsuitable_ids.append(image_dict["image_id"])

# All the image ids from 0 to 1499
image_ids = [i for i in range(1500)]

# Remove the unsuitable ids
filtered_ids = []
for id in image_ids:
    if id not in unsuitable_ids:
        filtered_ids.append(id)

# Checks to make sure that the code finds the correct ids
print(len(list(set(unsuitable_ids))))
print(len(list(set(filtered_ids))))
# Out:
# 941
# 559

# %%
filtered_ids[0:10]
# Out:
# [3, 4, 10, 11, 18, 25, 26, 27, 28, 29]

# %% [markdown]
# For each of the relevant ids, find the corresponding image, download it and add it to a list of loaded images.

# %%
image_data = df["images"][0]
image_data[0:5]
# Out:
# [{'id': 0,
#   'width': 1537,
#   'height': 2049,
#   'file_name': 'batch_1/000006.jpg',
#   'license': None,
#   'flickr_url': 'https://farm66.staticflickr.com/65535/33978196618_e30a59e0a8_o.png',
#   'coco_url': None,
#   'date_captured': None,
#   'flickr_640_url': 'https://farm66.staticflickr.com/65535/33978196618_632623b4fc_z.jpg'},
#  {'id': 1,
#   'width': 1537,
#   'height': 2049,
#   'file_name': 'batch_1/000008.jpg',
#   'license': None,
#   'flickr_url': 'https://farm66.staticflickr.com/65535/47803331152_ee00755a2e_o.png',
#   'coco_url': None,
#   'date_captured': None,
#   'flickr_640_url': 'https://farm66.staticflickr.com/65535/47803331152_19beae025a_z.jpg'},
#  {'id': 2,
#   'width': 1537,
#   'height': 2049,
#   'file_name': 'batch_1/000010.jpg',
#   'license': None,
#   'flickr_url': 'https://farm66.staticflickr.com/65535/40888872753_08ffb24902_o.png',
#   'coco_url': None,
#   'date_captured': None,
#   'flickr_640_url': 'https://farm66.staticflickr.com/65535/40888872753_631ab0f441_z.jpg'},
#  {'id': 3,
#   'width': 2049,
#   'height': 1537,
#   'file_name': 'batch_1/000019.jpg',
#   'license': None,
#   'flickr_url': 'https://farm66.staticflickr.com/65535/47803331492_0e1085ca55_o.png',
#   'coco_url': None,
#   'date_captured': None,
#   'flickr_640_url': 'https://farm66.staticflickr.com/65535/47803331492_b8c0e5aafe_z.jpg'},
#  {'id': 4,
#   'width': 1537,
#   'height': 2049,
#   'file_name': 'batch_1/000026.jpg',
#   'license': None,
#   'flickr_url': 'https://farm66.staticflickr.com/65535/33978199868_88ee160849_o.png',
#   'coco_url': None,
#   'date_captured': None,
#   'flickr_640_url': 'https://farm66.staticflickr.com/65535/33978199868_1bc379170a_z.jpg'}]

# %%
loaded_images = []

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

for datapoint in image_data:
    if datapoint["id"] in filtered_ids:
        url = datapoint["flickr_url"]
        req = urllib.request.Request(url, headers=headers)
        with urllib.request.urlopen(req) as response:
            image_data_bytes = response.read()
            image_data_array = np.frombuffer(image_data_bytes, np.uint8)
            img = cv2.imdecode(image_data_array, cv2.IMREAD_COLOR)
        loaded_images.append(img)

# %%
plt.imshow(loaded_images[112])

# %%
len(loaded_images)
# Out:
# 559

# %% [markdown]
# For each of the relevant ids, find the corresponding bounding boxes:

# %%
annotations = df["annotations"][0]
annotations[5]
# Out:
# {'id': 6,
#  'image_id': 3,
#  'category_id': 5,
#  'segmentation': [[354.0,
#    1268.0,
#    351.0,
#    1252.0,
#    347.0,
#    1237.0,
#    343.0,
#    1230.0,
#    339.0,
#    1220.0,
#    336.0,
#    1203.0,
#    331.0,
#    1197.0,
#    315.0,
#    1182.0,
#    310.0,
#    1172.0,
#    302.0,
#    1168.0,
#    281.0,
#    1147.0,
#    267.0,
#    1128.0,
#    255.0,
#    1108.0,
#    242.0,
#    1089.0,
#    231.0,
#    1068.0,
#    218.0,
#    1052.0,
#    212.0,
#    1032.0,
#    209.0,
#    1019.0,
#    213.0,
#    1009.0,
#    231.0,
#    994.0,
#    249.0,
#    984.0,
#    262.0,
#    976.0,
#    270.0,
#    974.0,
#    284.0,
#    966.0,
#    302.0,
#    956.0,
#    313.0,
#    950.0,
#    322.0,
#    942.0,
#    326.0,
#    939.0,
#    339.0,
#    938.0,
#    351.0,
#    933.0,
#    361.0,
#    925.0,
#    379.0,
#    920.0,
#    392.0,
#    925.0,
#    407.0,
#    940.0,
#    421.0,
#    958.0,
#    430.0,
#    969.0,
#    452.0,
#    994.0,
#    467.0,
#    1014.0,
#    475.0,
#    1030.0,
#    479.0,
#    1049.0,
#    481.0,
#    1071.0,
#    489.0,
#    1098.0,
#    491.0,
#    1114.0,
#    501.0,
#    1120.0,
#    528.0,
#    1142.0,
#    541.0,
#    1153.0,
#    552.0,
#    1166.0,
#    551.0,
#    1176.0,
#    555.0,
#    1177.0,
#    579.0,
#    1213.0,
#    601.0,
#    1250.0,
#    608.0,
#    1257.0,
#    610.0,
#    1265.0,
#    612.0,
#    1274.0,
#    615.0,
#    1273.0,
#    622.0,
#    1274.0,
#    627.0,
#    1282.0,
#    626.0,
#    1289.0,
#    626.0,
#    1297.0,
#    629.0,
#    1304.0,
#    629.0,
#    1327.0,
#    637.0,
#    1335.0,
#    641.0,
#    1345.0,
#    642.0,
#    1352.0,
#    639.0,
#    1384.0,
#    635.0,
#    1412.0,
#    636.0,
#    1420.0,
#    644.0,
#    1430.0,
#    648.0,
#    1432.0,
#    653.0,
#    1440.0,
#    656.0,
#    1448.0,
#    663.0,
#    1460.0,
#    662.0,
#    1467.0,
#    657.0,
#    1476.0,
#    651.0,
#    1482.0,
#    646.0,
#    1475.0,
#    643.0,
#    1459.0,
#    631.0,
#    1458.0,
#    629.0,
#    1451.0,
#    632.0,
#    1444.0,
#    623.0,
#    1434.0,
#    616.0,
#    1434.0,
#    611.0,
#    1417.0,
#    594.0,
#    1415.0,
#    592.0,
#    1396.0,
#    587.0,
#    1380.0,
#    578.0,
#    1375.0,
#    562.0,
#    1367.0,
#    551.0,
#    1365.0,
#    552.0,
#    1350.0,
#    543.0,
#    1351.0,
#    537.0,
#    1353.0,
#    525.0,
#    1339.0,
#    504.0,
#    1339.0,
#    492.0,
#    1328.0,
#    482.0,
#    1333.0,
#    463.0,
#    1315.0,
#    455.0,
#    1321.0,
#    448.0,
#    1318.0,
#    443.0,
#    1307.0,
#    438.0,
#    1300.0,
#    432.0,
#    1299.0,
#    427.0,
#    1295.0,
#    415.0,
#    1286.0,
#    406.0,
#    1290.0,
#    398.0,
#    1332.0,
#    394.0,
#    1332.0,
#    376.0,
#    1300.0,
#    374.0,
#    1292.0,
#    370.0,
#    1289.0,
#    359.0,
#    1276.0,
#    354.0,
#    1268.0]],
#  'area': 98379.5,
#  'bbox': [209.0, 920.0, 454.0, 562.0],
#  'iscrowd': 0}

# %%
bboxes = {}
for datapoint in annotations:
    id = datapoint["image_id"]
    bbox = datapoint["bbox"]
    if id in filtered_ids:
        try:
            boxes = bboxes[id]
            bboxes[id].append(bbox)
        except:
            bboxes[id] = [bbox]

# %%
bboxes[3]
# Out:
# [[209.0, 920.0, 454.0, 562.0],
#  [1212.0, 822.0, 179.0, 446.0],
#  [634.0, 1442.0, 29.0, 39.0],
#  [589.0, 548.0, 341.0, 405.0]]

# %%
len(bboxes.keys())
# Out:
# 559
